# %% [markdown]
# # Reading Tabular Data into DataFrames
#
# With Pandas we can easily read a file to a DataFrame. The method for reading a CSV file is `read_csv()` and for a JSON file is `read_json()`.
#
# ## ``read_csv()``
#
# `california_housing_test.csv` is California housing data from the 1990 US Census.
#
# The following read_csv code should run on both local Jupyter notebooks as well as Colab. The data file is available to Colab notebook by default in the sample_data folder.

# %%
import pandas as pd

# %%
pd.read_csv("sample_data/california_housing_test.csv").head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
# 4       850.0       237.0         2.9375             81700.0

# %% [markdown]
# Let's read this file again but this time save it as a DataFrame by providing an appropriate name:

# %%
ca_housing = pd.read_csv("sample_data/california_housing_test.csv")

# %% [markdown]
# ## `head()`
# Now we can look at the first few rows by `head()` function:

# %%
ca_housing.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
# 4       850.0       237.0         2.9375             81700.0

# %% [markdown]
# ## `describe()`
#
# `describe()` function is a fast way to get an overview of the basic statistics of the DataFrame:

# %%
ca_housing.describe()
# Out:
#          longitude    latitude  housing_median_age   total_rooms  \
# count  3000.000000  3000.00000         3000.000000   3000.000000
# mean   -119.589200    35.63539           28.845333   2599.578667
# std       1.994936     2.12967           12.555396   2155.593332
# min    -124.180000    32.56000            1.000000      6.000000
# 25%    -121.810000    33.93000           18.000000   1401.000000
# 50%    -118.485000    34.27000           29.000000   2106.000000
# 75%    -118.020000    37.69000           37.000000   3129.000000
# max    -114.490000    41.92000           52.000000  30450.000000
#
#        total_bedrooms    population  households  median_income  \
# count     3000.000000   3000.000000  3000.00000    3000.000000
# mean       529.950667   1402.798667   489.91200       3.807272
# std        415.654368   1030.543012   365.42271       1.854512
# min          2.000000      5.000000     2.00000       0.499900
# ...

# %% [markdown]
# ## `info()`
#
# Another way to get a high level summary is `info()`. This method prints information about a DataFrame including the index dtype and column dtypes, non-null values and memory usage.

# %%
ca_housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           3000 non-null   float64
#  1   latitude            3000 non-null   float64
#  2   housing_median_age  3000 non-null   float64
#  3   total_rooms         3000 non-null   float64
#  4   total_bedrooms      3000 non-null   float64
#  5   population          3000 non-null   float64
#  6   households          3000 non-null   float64
#  7   median_income       3000 non-null   float64
#  8   median_house_value  3000 non-null   float64
# dtypes: float64(9)
# memory usage: 211.1 KB

# %% [markdown]
# ## `.columns`
#
# Lists all the columns of the DataFrame:

# %%
ca_housing.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value'],
#       dtype='object')

# %% [markdown]
# ## `.shape`
#
# This DataFrame attribute provides the number of rows and columns of a DataFrame:

# %%
ca_housing.shape
# Out:
# (3000, 9)

# %% [markdown]
# # Anscombe's quartet
#
# Anscombe's quartet comprises four datasets that have nearly identical simple descriptive statistics, yet appear very different when graphed. Each dataset consists of eleven (x,y) points. They were constructed in 1973 by the statistician Francis Anscombe to demonstrate both **the importance of graphing data before analyzing it** and **the effect of outliers on statistical properties**. He described the article as being intended to counter the impression among statisticians that "numerical calculations are exact, but graphs are rough".

# %% [markdown]
# ## `read_json()`
#
# `anscombe.json` contains a copy of [Anscombe's quartet](https://en.wikipedia.org/wiki/Anscombe%27s_quartet). The file contains 11 data points for 4 series. These series can be described by a similar statistics but in fact are very different from each other when plotted:

# %%
anscombe = pd.read_json("sample_data/anscombe.json")
anscombe.head(20)
# Out:
#    Series   X      Y
# 0       I  10   8.04
# 1       I   8   6.95
# 2       I  13   7.58
# 3       I   9   8.81
# 4       I  11   8.33
# 5       I  14   9.96
# 6       I   6   7.24
# 7       I   4   4.26
# 8       I  12  10.84
# 9       I   7   4.81
# 10      I   5   5.68
# 11     II  10   9.14
# 12     II   8   8.14
# 13     II  13   8.74
# 14     II   9   8.77
# 15     II  11   9.26
# 16     II  14   8.10
# 17     II   6   6.13
# 18     II   4   3.10
# 19     II  12   9.13

# %% [markdown]
# ## Visualizing with Seaborn
#
# Seaborn is a Python data visualization library based on matplotlib. It provides a high-level interface for drawing attractive and informative statistical graphics.

# %%
# %matplotlib inline

# %%
import seaborn as sns

# Show the results of a linear regression within each dataset
sns.lmplot(x="X", y="Y", col="Series", hue="Series", data=anscombe,
           col_wrap=2, ci=None, palette="muted", height=4)

# %% [markdown]
# ## Filter rows

# %%
anscombe[anscombe.Series == 'I']
# Out:
#    Series   X      Y
# 0       I  10   8.04
# 1       I   8   6.95
# 2       I  13   7.58
# 3       I   9   8.81
# 4       I  11   8.33
# 5       I  14   9.96
# 6       I   6   7.24
# 7       I   4   4.26
# 8       I  12  10.84
# 9       I   7   4.81
# 10      I   5   5.68

# %%
# Splitting the DataFrame into 4 based on their Series values
anscombe_I = anscombe[anscombe.Series == 'I']
anscombe_II = anscombe[anscombe.Series == 'II']
anscombe_III = anscombe[anscombe.Series == 'III']
anscombe_IV = anscombe[anscombe.Series == 'IV']

# %% [markdown]
# Using `describe()` method to get the statistics:

# %%
# Applying the descibe method on all the 4 DataFrames
desc_I = anscombe_I.describe()
desc_II = anscombe_II.describe()
desc_III = anscombe_III.describe()
desc_IV = anscombe_IV.describe()

# Renaming the column names
desc_I.columns = ['X_I', 'Y_I']
desc_II.columns = ['X_II', 'Y_II']
desc_III.columns = ['X_III', 'Y_III']
desc_IV.columns = ['X_IV', 'Y_IV']

# Joining the summary DataFrames
summary = desc_I.join(desc_II)
summary = summary.join(desc_III)
summary = summary.join(desc_IV)

# Reordering the columns
summary[['X_I', 'X_II', 'X_III', 'X_IV', 'Y_I', 'Y_II', 'Y_III', 'Y_IV']]
# Out:
#              X_I       X_II      X_III       X_IV       Y_I       Y_II  \
# count  11.000000  11.000000  11.000000  11.000000  11.00000  11.000000
# mean    9.000000   9.000000   9.000000   9.000000   7.50000   7.500909
# std     3.316625   3.316625   3.316625   3.316625   2.03289   2.031657
# min     4.000000   4.000000   4.000000   8.000000   4.26000   3.100000
# 25%     6.500000   6.500000   6.500000   8.000000   6.31500   6.695000
# 50%     9.000000   9.000000   9.000000   8.000000   7.58000   8.140000
# 75%    11.500000  11.500000  11.500000   8.000000   8.57000   8.950000
# max    14.000000  14.000000  14.000000  19.000000  10.84000   9.260000
#
#            Y_III       Y_IV
# count  11.000000  11.000000
# mean    7.500000   7.500909
# std     2.030424   2.030579
# min     5.390000   5.250000
# 25%     6.250000   6.170000
# 50%     7.110000   7.040000
# 75%     7.980000   8.190000
# max    12.740000  12.500000

# %% [markdown]
# ## Loading a sample DataFrame from a package
#
# Some packages contain sample data that can be loaded by a method specific to that library. For instance seaborn sample dataset can be loaded to a DataFrame by `sns.load_dataset()`:

# %%
# Load the example dataset for Anscombe's quartet
df = sns.load_dataset("anscombe")
df.head()
# Out:
#   dataset     x     y
# 0       I  10.0  8.04
# 1       I   8.0  6.95
# 2       I  13.0  7.58
# 3       I   9.0  8.81
# 4       I  11.0  8.33

# %% [markdown]
# You can access a list of all seaborn sample datasets by `sns.get_dataset_names()`.

# %% [markdown]
# ## Reading from Excel
#
# For this example we are using an Excel file that is located in the Github folder sample_date: `datasets.xlsx`
#
# If you are using Colab you will need to upload this file manually to your sample_date folder.

# %%
import pandas as pd
 
iris = pd.read_excel('sample_data/datasets.xlsx', sheet_name='iris')
iris.head()
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
mtcars = pd.read_excel('sample_data/datasets.xlsx', sheet_name='mtcars')
mtcars.head()
# Out:
#     mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  carb
# 0  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4     4
# 1  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4     4
# 2  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4     1
# 3  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3     1
# 4  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3     2

# %% [markdown]
# For more information I refer you to the help page `pd.read_excel?`.

# %% [markdown]
# ## Writing to CSV
#
# Let's write the `mtcars` DataFrame that we just read form our Excel file into a separate CSV file using the `to_csv()` function.
#
# In order to do this we use this method on the DataFrame we would like to export. If you type `mtcars.to_` and the `<TAB>` you can see all the other options available to you:

# %%
mtcars.to_csv('sample_data/mtcars.csv')

# %% [markdown]
# ## Writing to Excel
#
# Let's create a new Excel file using `anscombe` and `ca_housing` DataFrames that we imported above.

# %%
# First create a writer object with a filename
writer = pd.ExcelWriter('sample_data/Pandas-Example.xlsx')

# Add DataFrames that need to be exported to the sheet defined above
anscombe.to_excel(writer,'anscombe',index=False)
ca_housing.to_excel(writer,'ca_housing',index=False)

# Write it to disk
writer.save()
